# %%
import wget
import pandas as pd
from nltk import WordPunctTokenizer
from collections import defaultdict, Counter
import numpy as np
import random

# %%
file_names = ['Арап Петра Великого.txt', 'Дубровский.txt', 'Египетские ночи.txt', 'История Пугачёва.txt',
              'История села Горюхина.txt', 'Капитанская дочка.txt', 'Кирджали.txt', 'Пиковая дама.txt',
              'Повести Белкина.txt', 'Рославлев.txt']

# %%
for file_name in file_names:
    wget.download(f'https://raw.githubusercontent.com/d0rj/RusLit/main/prose/Pushkin/{file_name}')

# %%
data = pd.DataFrame()
for file_name in file_names:
    with open(file_name, 'r', encoding='utf-8') as file:
        text = file.read()

        df = pd.DataFrame({
            file_name.replace('.txt', ''): text
        }.items(), columns=['name', 'text'])
        data = pd.concat([data, df], ignore_index=True)

# %%
data
# Out:
#                     name                                               text
# 0    Арап Петра Великого  Александр Пушкин\nАРАП ПЕТРА ВЕЛИКОГО\nГЛАВА I...
# 1             Дубровский  \nАлександр Сергеевич Пушкин. Дубровский\n\n\n...
# 2        Египетские ночи  Александр Пушкин\nЕГИПЕТСКИЕ НОЧИ\nГЛАВА I\n— ...
# 3       История Пугачёва  \nАлександр Сергеевич Пушкин\nИстория Пугачева...
# 4  История села Горюхина  Александр Пушкин\nИСТОРИЯ СЕЛА ГОРЮХИНА\nЕсли ...
# 5      Капитанская дочка  Александр Пушкин\nКАПИТАНСКАЯ ДОЧКА\nБереги че...
# 6               Кирджали  Александр Пушкин\nКИРДЖАЛИ\nПОВЕСТЬ\nКирджали ...
# 7           Пиковая дама  Александр Пушкин\nПИКОВАЯ ДАМА\nПиковая дама о...
# 8        Повести Белкина  \nПовести покойного Ивана Петровича Белкина\n\...
# 9              Рославлев  Александр Пушкин\nРОСЛАВЛЕВ\nЧитая «Рославлева...

# %%
tokenizer = WordPunctTokenizer()

# %%
def get_tokens(text):
    return tokenizer.tokenize(text.lower())

# %%
text = ' '.join(data['text'].tolist())

# %%
tokens = get_tokens(text)

# %%
tokens[:10]
# Out:
# ['александр',
#  'пушкин',
#  'арап',
#  'петра',
#  'великого',
#  'глава',
#  'i',
#  'я',
#  'в',
#  'париже']

# %%
def generate_trigrams(tokens):
    trigrams = []
    for i in range(len(tokens) - 2):
        trigrams.append((tokens[i], tokens[i + 1], tokens[i + 2]))
    
    return trigrams

# %%
trigrams = generate_trigrams(tokens)

# %%
trigrams[2]
# Out:
# ('арап', 'петра', 'великого')

# %%
model = defaultdict(Counter)

# %%
for w1, w2, w3 in trigrams:
    model[(w1, w2)][w3] += 1

# %%
model
# Out:
# defaultdict(collections.Counter,
#             {('александр',
#               'пушкин'): Counter({'арап': 1,
#                       'египетские': 1,
#                       'история': 1,
#                       'капитанская': 1,
#                       'кирджали': 1,
#                       'пиковая': 1,
#                       'рославлев': 1}),
#              ('пушкин', 'арап'): Counter({'петра': 1}),
#              ('арап', 'петра'): Counter({'великого': 1}),
#              ('петра',
#               'великого'): Counter({'глава': 1, '.': 1, 'они': 1, ',': 1}),
#              ('великого', 'глава'): Counter({'i': 1}),
#              ('глава', 'i'): Counter({'я': 1, '.': 1, '—': 1, 'сержант': 1}),
#              ('i', 'я'): Counter({'в': 1}),
#              ('я',
#               'в'): Counter({'париже': 1,
#                       'петербурге': 1,
#                       'театр': 1,
#                       'симбирск': 1,
#                       'недоумении': 1,
#                       'ней': 2,
#                       'бешенстве': 4,
#                       'коротких': 1,
#                       'них': 1,
#                       'эту': 1,
#                       'такой': 1,
#                       'службу': 1,
#                       'долгу': 1,
#                       'нашем': 1,
#                       'лицо': 1,
#                       'мелком': 1,
#                       'другую': 1,
#                       'отчаянии': 1,
#                       'саду': 1}),
#              ('в', 'париже'): Counter({':': 1, 'общее': 1, ',': 2, 'm': 1}),
#              ('париже', ':'): Counter({'я': 1}),
#              (':',
#               'я'): Counter({'начал': 1,
#                       ',': 1,
#                       'предчувствовал': 1,
#                       'вообразил': 1,
#                       'решился': 1,
#                       'сейчас': 1,
#                       'не': 4,
#                       'вчера': 1,
#                       'чай': 1,
#                       'спешу': 1,
#                       'знаю': 1,
#                       'мог': 1,
#                       'привык': 1,
#                       'был': 1,
#                       'перепил': 1,
#                       'на': 1,
#                       'видел': 1,
#                       'ни': 1}),
#              ('я', 'начал'): Counter({'жить': 1, 'и': 1}),
#              ('начал', 'жить'): Counter({',': 1}),
#              ('жить', ','): Counter({'а': 1, '–': 1, 'вместе': 1}),
#              (',',
#               'а'): Counter({'не': 23,
#                       'любовь': 1,
#                       'головин': 1,
#                       'я': 25,
#                       'робронды': 1,
#                       'дамы': 1,
#                       'прежние': 1,
#                       'нынешние': 1,
#                       'завтра': 2,
#                       'мы': 7,
#                       'ее': 3,
#                       'жена': 1,
#                       'об': 2,
#                       'как': 3,
#                       'то': 6,
#                       'даже': 1,
#                       'мне': 3,
#                       'признаюсь': 1,
#                       'каков': 1,
#                       'чести': 1,
#                       'наш': 1,
#                       'наше': 1,
#                       'он': 7,
#                       'про': 1,
#                       'посмотрим': 1,
#                       'дружбу': 1,
#                       'потом': 7,
#                       'старушка': 2,
#                       'до': 2,
#                       'татьяна': 1,
#                       'лучшего': 1,
#                       'батюшка': 1,
#                       'что': 5,
#                       'пред': 1,
#                       'иногда': 6,
#                       'гости': 1,
#                       'старинный': 1,
#                       'лошадей': 1,
#                       'в': 14,
#                       'из': 4,
#                       'между': 2,
#                       'ему': 1,
#                       'полагает': 1,
#                       'по': 1,
#                       'посему': 2,
#                       'здоровье': 1,
#                       'положение': 1,
#                       'тот': 1,
#                       'ей': 3,
#                       'свиньи': 1,
#                       'андрей': 1,
#                       'достанутся': 1,
#                       'коли': 3,
#                       'туда': 1,
#                       'вы': 4,
#                       'шабашкин': 1,
#                       '?': 1,
#                       'слуга': 1,
#                       'пустился': 1,
#                       'дубровского': 1,
#                       'с': 7,
#                       'единственно': 1,
#                       'сынок': 1,
#                       'нынче': 1,
#                       'проку': 1,
#                       'деньги': 1,
#                       'жаль': 1,
#                       'на': 9,
#                       'после': 2,
#                       'ты': 7,
#                       'только': 1,
#                       'уж': 1,
#                       'тогда': 1,
#                       'около': 1,
#                       'пуще': 1,
#                       'теперь': 7,
#                       '.': 1,
#                       'марья': 2,
#                       'покаместь': 1,
#                       'саша': 1,
#                       'сестрица': 1,
#                       'малина': 1,
#                       'одного': 1,
#                       'степка': 1,
#                       'сабля': 1,
#                       'жен': 1,
#                       'стрельцы': 1,
#                       'казаки': 2,
#                       'второй': 2,
#                       'оные': 1,
#                       'ханских': 1,
#                       'представляю': 1,
#                       'именно': 2,
#                       'весною': 1,
#                       'вперед': 1,
#                       'без': 1,
#                       'другие': 1,
#                       'бедный': 1,
#                       'деревянные': 1,
#                       'другого': 1,
#                       'поодиночке': 1,
#                       'редко': 1,
#                       'убаши': 1,
#                       'оттуда': 3,
#                       'незнакомец': 1,
#                       'пехоту': 1,
#                       'гарнизонная': 1,
#                       'киргизцы': 1,
#                       'ближайшим': 1,
#                       'рота': 1,
#                       'сам': 9,
#                       'ехал': 1,
#                       'сообщено': 1,
#                       'тем': 1,
#                       'поспешное': 1,
#                       'другую': 4,
#                       'вал': 1,
#                       'казакам': 1,
#                       'избу': 1,
#                       'томский': 1,
#                       'целые': 1,
#                       'сакмарский': 1,
#                       'раненых': 1,
#                       'несколько': 1,
#                       'послушные': 1,
#                       'зло': 1,
#                       'праведную': 1,
#                       'семейство': 1,
#                       'паче': 1,
#                       'вашему': 1,
#                       'можно': 1,
#                       'от': 5,
#                       'трое': 1,
#                       'третья': 1,
#                       'они': 4,
#                       'вторая': 1,
#                       'прозвания': 1,
#                       'иностранного': 1,
#                       'отчества': 1,
#                       'ныне': 1,
#                       'сей': 1,
#                       'там': 4,
#                       'мансурова': 1,
#                       'женщин': 1,
#                       'буде': 2,
#                       'сверх': 1,
#                       'провиант': 1,
#                       'прямо': 2,
#                       'простота': 1,
#                       'через': 1,
#                       'офицеры': 1,
#                       'михельсон': 1,
#                       'доносчик': 1,
#                       'майора': 1,
#                       'отряд': 1,
#                       'невольники': 1,
#                       'при': 2,
#                       'князь': 1,
#                       'казака': 1,
#                       'черных': 1,
#                       'кобякова': 1,
#                       '14': 1,
#                       '22': 1,
#                       'смело': 1,
#                       'ночью': 1,
#                       'когда': 1,
#                       'ворон': 1,
#                       'городок': 1,
#                       'рекрутский': 1,
#                       'те': 1,
#                       'другой': 1,
#                       'сидевшие': 1,
#                       'сочинитель': 1,
#                       'стряпчий': 1,
#                       'его': 3,
#                       'гордые': 1,
#                       'прочие': 1,
#                       'боярин': 1,
#                       'дорого': 1,
#                       'жили': 1,
#                       'никто': 1,
#                       'отдаваемые': 1,
#                       'другая': 1,
#                       'старик': 1,
#                       'отвезли': 1,
#                       'сколько': 1,
#                       'честь': 1,
#                       'савельичу': 1,
#                       'сверху': 1,
#                       'стоит': 1,
#                       'так': 1,
#                       'зурин': 2,
#                       'покамест': 2,
#                       'всего': 1,
#                       'денег': 1,
#                       'тебя': 3,
#                       'кажется': 1,
#                       'твое': 1,
#                       'какое': 1,
#                       'если': 1,
#                       'и': 1,
#                       'швабрин': 1,
#                       'верный': 1,
#                       'палашку': 1,
#                       'топить': 1,
#                       'юлая': 1,
#                       'командиров': 1,
#                       'юлай': 1,
#                       'посмотри': 1,
#                       'сгинул': 1,
#                       'парится': 1,
#                       'четвертый': 1,
#                       'твои': 1,
#                       'нападения': 1,
#                       'савельич': 1,
#                       'стены': 1,
#                       'других': 1,
#                       'о': 1,
#                       'сегодня': 1,
#                       'хозяюшку': 1,
#                       'матушка': 1,
#                       'вместе': 4,
#                       'голубые': 1,
#                       'двери': 1,
#                       'огромный': 1,
#                       'лошади': 1,
#                       'много': 1,
#                       'михайлаки': 1,
#                       'может': 1,
#                       'за': 1,
#                       'атаганы': 1,
#                       'все': 1,
#                       'казанова': 1,
#                       'камердинер': 1,
#                       'кому': 1,
#                       'конногвардеец': 1,
#                       'душа': 1,
#                       'сердце': 1,
#                       'худощавый': 1,
#                       'открытый': 1,
#                       'также': 1,
#                       'названия': 1,
#                       'носил': 1,
#                       'держал': 1,
#                       'моя': 1,
#                       'полковые': 1,
#                       'впрочем': 1,
#                       'графиня': 1,
#                       'убийство': 1,
#                       'некоторые': 1,
#                       'воля': 1,
#                       'для': 1,
#                       'езды': 1,
#                       'полю': 1,
#                       'жадрина': 1,
#                       'добрая': 1,
#                       'мертвый': 1,
#                       'во': 1,
#                       'кости': 1,
#                       'дочь': 2,
#                       'иные': 1,
#                       'вас': 1,
#                       'слуги': 1,
#                       'лиза': 2,
#                       'молодой': 1,
#                       'песок': 1,
#                       'летела': 1,
#                       'дорога': 1,
#                       'мой': 1,
#                       'берестов': 1,
#                       'муромский': 2,
#                       'алексей': 1,
#                       'слегка': 1,
#                       'имение': 1,
#                       'уже': 1,
#                       'рукава': 1,
#                       'княжна': 1,
#                       'm': 1,
#                       'дома': 1,
#                       'наша': 1,
#                       'меры': 1}),
#              ('а',
#               'не'): Counter({'дышать': 1,
#                       'кавалеру': 1,
#                       'слышать': 1,
#                       'крепостные': 1,
#                       'выдадим': 1,
#                       'кто': 1,
#                       'присутствия': 1,
#                       'грабит': 1,
#                       'догадаешься': 1,
#                       'надо': 1,
#                       'чей': 1,
#                       'шаматон': 1,
#                       'для': 1,
#                       'полтина': 1,
#                       'коллежский': 1,
#                       'семейственным': 1,
#                       'худо': 1,
#                       'гостя': 1,
#                       'бабьим': 1,
#                       'буду': 1,
#                       'в': 1,
#                       'правосудия': 1,
#                       'андрюшка': 1,
#                       'изъявление': 1,
#                       'папенькина': 1}),
#              ('не', 'дышать'): Counter({'.': 1}),
#              ('дышать', '.'): Counter({'дмитриев': 1}),
#              ('.', 'дмитриев'): Counter({'.': 1}),
#              ('дмитриев', '.'): Counter({'журнал': 1}),
#              ('.', 'журнал'): Counter({'путешественника': 1}),
#              ('журнал', 'путешественника'): Counter({'.': 1}),
#              ('путешественника', '.'): Counter({'в': 1}),
#              ('.',
#               'в'): Counter({'числе': 4,
#                       'присутствии': 1,
#                       'первом': 1,
#                       'таком': 1,
#                       'углу': 2,
#                       'ожидании': 1,
#                       'сем': 4,
#                       'это': 19,
#                       'одну': 4,
#                       'старинной': 1,
#                       'эту': 12,
#                       'гостиной': 3,
#                       'ней': 6,
#                       'домашнем': 1,
#                       'одном': 4,
#                       'некоторых': 2,
#                       'сие': 8,
#                       'том': 1,
#                       'тот': 6,
#                       'передней': 1,
#                       'зале': 3,
#                       'сию': 3,
#                       '**': 1,
#                       'эпоху': 2,
#                       'первой': 3,
#                       '9': 2,
#                       'них': 1,
#                       'этой': 1,
#                       'год': 1,
#                       'этих': 2,
#                       'ваших': 1,
#                       '30': 1,
#                       'самом': 18,
#                       'уборной': 1,
#                       'шалаше': 1,
#                       'журналах': 1,
#                       'своей': 1,
#                       'кабинете': 1,
#                       'нем': 5,
#                       'соседстве': 1,
#                       '1720': 1,
#                       'царствование': 1,
#                       '1740': 1,
#                       'яицком': 1,
#                       'оренбурге': 5,
#                       'тюрьмах': 1,
#                       'его': 1,
#                       'xiv': 1,
#                       '1681': 1,
#                       '1683': 1,
#                       'изобильном': 1,
#                       'день': 2,
#                       '1791': 1,
#                       '1775': 1,
#                       'смутное': 1,
#                       'случае': 3,
#                       'городе': 2,
#                       'уральске': 1,
#                       'допросе': 1,
#                       'селениях': 1,
#                       'оренбургском': 1,
#                       'версте': 1,
#                       'церкви': 1,
#                       'начале': 2,
#                       'истине': 1,
#                       'то': 9,
#                       'молодых': 1,
#                       '1766': 1,
#                       '1771': 1,
#                       'этот': 3,
#                       'примечаниях': 1,
#                       '1762': 1,
#                       '.': 1,
#                       'ночь': 1,
#                       'крепости': 4,
#                       'сей': 2,
#                       'письмах': 1,
#                       'европе': 1,
#                       '1770': 1,
#                       'ответ': 1,
#                       'приложении': 3,
#                       'записках': 2,
#                       'октябре': 1,
#                       'декабре': 1,
#                       'малыковку': 1,
#                       'самое': 2,
#                       'одной': 2,
#                       'берде': 1,
#                       'озерной': 1,
#                       'кузницах': 1,
#                       'рычкове': 1,
#                       'сеитовской': 1,
#                       'лагере': 1,
#                       'казани': 1,
#                       'уфе': 1,
#                       'сих': 1,
#                       'казармах': 1,
#                       'саратове': 1,
#                       'конце': 2,
#                       'деревне': 2,
#                       'коспорье': 1,
#                       'москве': 2,
#                       'целом': 1,
#                       'десятый': 1,
#                       'книжке': 1,
#                       '1812': 1,
#                       '1820': 1,
#                       'самый': 1,
#                       'нежности': 2,
#                       'последний': 1,
#                       'три': 1,
#                       'ту': 2,
#                       'походе': 1,
#                       'одно': 2,
#                       'черной': 1,
#                       'доме': 2,
#                       'богоспасаемой': 1,
#                       'клевете': 1,
#                       '1772': 1,
#                       'комнате': 2,
#                       'наше': 2,
#                       'назначенный': 1,
#                       'сенях': 2,
#                       'оренбург': 1,
#                       'тридцати': 1,
#                       'первый': 2,
#                       'свете': 1,
#                       'спальне': 1,
#                       'десять': 1,
#                       'спальню': 1,
#                       'сердце': 1,
#                       'мутных': 1,
#                       'этом': 1,
#                       'простых': 1,
#                       'следующий': 1,
#                       '1815': 1,
#                       '***': 1,
#                       'четырех': 1,
#                       'картинах': 1,
#                       'свое': 1,
#                       '1816': 1,
#                       'трех': 1,
#                       'другой': 1,
#                       'мучительном': 1,
#                       'сени': 1,
#                       'молодости': 1,
#                       'будни': 1,
#                       'столицах': 1,
#                       'два': 1,
#                       '.,': 1,
#                       'библиотеке': 1,
#                       'прозе': 1,
#                       'город': 1,
#                       'плену': 1}),
#              ('в',
#               'числе'): Counter({'молодых': 1,
#                       'тридцати': 1,
#                       'трех': 1,
#                       'тысячи': 1,
#                       'главных': 1,
#                       'последних': 1,
#                       'шестисот': 1,
#                       'убитых': 1,
#                       'пятисот': 1,
#                       'двух': 1,
#                       'зрителей': 1,
#                       'отличившихся': 1}),
#              ('числе', 'молодых'): Counter({'людей': 1}),
#              ('молодых', 'людей'): Counter({',': 4, 'тут': 1}),
#              ('людей',
#               ','): Counter({'отправленных': 1,
#                       'воспитанных': 1,
#                       'было': 1,
#                       'так': 1,
#                       'чтоб': 1,
#                       'коих': 1,
#                       'даже': 1,
#                       '–': 1,
#                       'старшине': 1,
#                       'находившихся': 1,
#                       'был': 1,
#                       'с': 1,
#                       'вооруженных': 1,
#                       'как': 2,
#                       'погребенных': 1,
#                       'осуждавших': 1,
#                       'возрастающую': 1,
#                       '—': 1}),
#              (',', 'отправленных'): Counter({'петром': 1}),
#              ('отправленных', 'петром'): Counter({'великим': 1}),
#              ('петром', 'великим'): Counter({'в': 1}),
#              ('великим', 'в'): Counter({'чужие': 1}),
#              ('в', 'чужие'): Counter({'края': 1, 'руки': 2}),
#              ('чужие', 'края'): Counter({',': 1}),
#              ('края',
#               ','): Counter({'для': 1,
#                       'и': 1,
#                       'следовательно': 1,
#                       'с': 1,
#                       'где': 2}),
#              (',',
#               'для'): Counter({'приобретения': 1,
#                       'дорогих': 1,
#                       'божия': 1,
#                       'него': 1,
#                       'них': 2,
#                       'вас': 1,
#                       'рассуждения': 1,
#                       'которого': 2,
#                       'коих': 1,
#                       'спасения': 1,
#                       'их': 1,
#                       'ношения': 1,
#                       'ободрения': 1,
#                       'уличения': 1,
#                       'преграждения': 1,
#                       'которых': 2,
#                       'себя': 1,
#                       'меня': 4,
#                       'тогдашнего': 1,
#                       'здоровья': 1,
#                       'молдаван': 1,
#                       'валахов': 1,
#                       'нее': 2}),
#              ('для', 'приобретения'): Counter({'сведений': 1}),
#              ('приобретения', 'сведений'): Counter({',': 1}),
#              ('сведений', ','): Counter({'необходимых': 1}),
#              (',', 'необходимых'): Counter({'государству': 1}),
#              ('необходимых', 'государству'): Counter({'преобразованному': 1}),
#              ('государству', 'преобразованному'): Counter({',': 1}),
#              ('преобразованному', ','): Counter({'находился': 1}),
#              (',',
#               'находился'): Counter({'его': 1,
#                       'он': 1,
#                       'при': 1,
#                       'в': 1,
#                       'сильный': 1}),
#              ('находился',
#               'его'): Counter({'крестник': 1, 'противник': 1, 'дом': 1}),
#              ('его', 'крестник'): Counter({',': 1}),
#              ('крестник', ','): Counter({'арап': 1}),
#              (',', 'арап'): Counter({'ибрагим': 1, ',': 1}),
#              ('арап', 'ибрагим'): Counter({'.': 1}),
#              ('ибрагим', '.'): Counter({'он': 1, 'несчастный': 1}),
#              ('.',
#               'он'): Counter({'обучался': 1,
#                       'отговаривался': 1,
#                       'чувствовал': 2,
#                       'даже': 1,
#                       'повсюду': 1,
#                       'видел': 2,
#                       'благословил': 1,
#                       'возвратился': 2,
#                       'любил': 2,
#                       'стоял': 2,
#                       'все': 2,
#                       'сел': 2,
#                       'старался': 1,
#                       'по': 1,
#                       'находился': 2,
#                       'увидел': 3,
#                       'день': 1,
#                       'почитал': 1,
#                       'горел': 1,
#                       'повторял': 1,
#                       'плакал': 1,
#                       'оделся': 1,
#                       'тщетно': 1,
#                       'происходил': 1,
#                       'поехал': 4,
#                       'оставил': 3,
#                       'потребовал': 3,
#                       'наконец': 1,
#                       'расхаживал': 1,
#                       'был': 30,
#                       'поспешил': 2,
#                       'вышел': 4,
#                       'отказался': 1,
#                       'написал': 2,
#                       'в': 2,
#                       'забывал': 1,
#                       'поспешно': 2,
#                       'лишился': 2,
#                       'воображал': 1,
#                       'решился': 5,
#                       'ехал': 2,
#                       'хотел': 5,
#                       'смотрел': 1,
#                       'силился': 1,
#                       'замолчал': 1,
#                       'расположился': 2,
#                       'знал': 2,
#                       'грозно': 1,
#                       'узнал': 1,
#                       'торопливо': 1,
#                       'взглянул': 2,
#                       'лежал': 1,
#                       'шел': 2,
#                       'невольно': 1,
#                       'нас': 1,
#                       'представил': 1,
#                       'входил': 1,
#                       'послал': 2,
#                       'приехал': 4,
#                       'малый': 1,
#                       'бы': 1,
#                       'отомстил': 1,
#                       'попытался': 1,
#                       'предлогает': 1,
#                       'не': 9,
#                       'с': 4,
#                       'молчал': 1,
#                       'схватил': 2,
#                       'имел': 3,
#                       'отвечал': 2,
#                       'говорил': 3,
#                       'упрям': 1,
#                       'долго': 1,
#                       'тихо': 1,
#                       'взял': 1,
#                       'о': 1,
#                       'повалил': 1,
#                       'пособит': 1,
#                       'упал': 1,
#                       'успел': 1,
#                       'избегал': 1,
#                       'прикидывался': 1,
#                       'вел': 1,
#                       'признавался': 1,
#                       'писал': 1,
#                       'уже': 1,
#                       'спесиво': 1,
#                       'поглядел': 2,
#                       'понял': 1,
#                       'проговорил': 1,
#                       'устыдился': 1,
#                       'простодушно': 1,
#                       'остановился': 5,
#                       'принимал': 1,
#                       'нашел': 1,
#                       'после': 1,
#                       'орошает': 1,
#                       'производится': 1,
#                       'отличался': 1,
#                       'убеждал': 1,
#                       'намерен': 1,
#                       'донес': 2,
#                       'обещал': 1,
#                       'увещевал': 1,
#                       'предписал': 1,
#                       'приложился': 1,
#                       'обратился': 1,
#                       'обошелся': 1,
#                       'пошел': 5,
#                       'тотчас': 3,
#                       'отступил': 2,
#                       'выстроился': 1,
#                       'ничего': 1,
#                       'держал': 2,
#                       'именовался': 1,
#                       'вместе': 1,
#                       'занял': 2,
#                       'испугался': 1,
#                       'целых': 1,
#                       'немедленно': 1,
#                       'уверил': 2,
#                       'служил': 1,
#                       'безоговорочно': 1,
#                       'кинулся': 1,
#                       'сказал': 1,
#                       'грозился': 1,
#                       'ежечасно': 1,
#                       'очутился': 1,
#                       'един': 1,
#                       'ездил': 1,
#                       'приездом': 1,
#                       'ободрил': 1,
#                       'укрепил': 1,
#                       'ею': 1,
#                       'надеялся': 3,
#                       'поклялся': 1,
#                       'стал': 6,
#                       'обрадовался': 1,
#                       'полагал': 1,
#                       'запечатал': 1,
#                       'умер': 1,
#                       'принял': 3,
#                       'двинулся': 1,
#                       'думал': 2,
#                       'вызвался': 1,
#                       'их': 1,
#                       'отовсюду': 1,
#                       'вошел': 1,
#                       'на': 1,
#                       'велел': 3,
#                       'сопровождал': 1,
#                       'выступил': 1,
#                       'отряжен': 1,
#                       ',': 5,
#                       'обошел': 1,
#                       'открыл': 1,
#                       'приказал': 1,
#                       'пустился': 1,
#                       'свиделся': 1,
#                       'посажен': 1,
#                       'скончался': 2,
#                       'осужден': 1,
#                       'воображает': 1,
#                       'оказался': 1,
#                       'исполнен': 1,
#                       'играет': 1,
#                       'играл': 1,
#                       'ахнул': 1,
#                       'явился': 2,
#                       'мало': 1,
#                       'посматривал': 1,
#                       'одет': 1,
#                       'проводил': 1,
#                       'вас': 1,
#                       'очень': 1,
#                       'один': 2,
#                       'запер': 1,
#                       'нимало': 1,
#                       'оглядывался': 1,
#                       'вручил': 1,
#                       'подошел': 2,
#                       'объявил': 1,
#                       'услышал': 2,
#                       'часто': 1,
#                       'проворно': 1,
#                       'отворотился': 1,
#                       'осматривал': 1,
#                       'мне': 1,
#                       'говорит': 1,
#                       'обходится': 1,
#                       'согласился': 1,
#                       'улегся': 1,
#                       'казался': 3,
#                       'трусил': 1,
#                       'сам': 1,
#                       'было': 1,
#                       'выслал': 1,
#                       'повторил': 1,
#                       'усмехнулся': 1,
#                       'строго': 1,
#                       'насвистывал': 1,
#                       'пристал': 1,
#                       'для': 1,
#                       'вынул': 2,
#                       'медленно': 1,
#                       'встретил': 1,
#                       'одной': 1,
#                       'дожидался': 1,
#                       'ее': 1,
#                       'вспомнил': 1,
#                       'ставил': 1,
#                       'того': 1,
#                       'остался': 1,
#                       'окаменел': 1,
#                       'спустился': 1,
#                       'верил': 1,
#                       'поклонился': 1,
#                       'проснулся': 1,
#                       'отсчитал': 1,
#                       'сидит': 1,
#                       'охотно': 1,
#                       'довольствовался': 1,
#                       'вспыхнул': 1,
#                       'приближался': 1,
#                       'прицелился': 1,
#                       'хлоп': 1,
#                       'медлил': 1,
#                       'помог': 2,
#                       'уговорил': 1,
#                       'отправил': 1,
#                       'ударил': 1,
#                       'разрешал': 1,
#                       'предвидел': 1,
#                       'молча': 1,
#                       'поминутно': 1,
#                       'пощупал': 1,
#                       'простился': 1,
#                       'воротился': 1,
#                       'выстроил': 1,
#                       'бесился': 1,
#                       'первый': 1,
#                       'же': 1,
#                       'может': 1,
#                       'употребил': 1,
#                       'решил': 1,
#                       'ушел': 1,
#                       'бросился': 1,
#                       'вновь': 1,
#                       'влюбился': 1,
#                       'тут': 1,
#                       'принадлежал': 1,
#                       'успокоил': 1}),
#              ('он', 'обучался'): Counter({'в': 1}),
#              ('обучался', 'в'): Counter({'парижском': 1}),
#              ('в', 'парижском'): Counter({'военном': 1}),
#              ('парижском', 'военном'): Counter({'училище': 1}),
#              ('военном', 'училище'): Counter({',': 1}),
#              ('училище', ','): Counter({'выпущен': 1, 'но': 1}),
#              (',', 'выпущен'): Counter({'был': 1}),
#              ('выпущен', 'был'): Counter({'капитаном': 1, 'корнетом': 1}),
#              ('был', 'капитаном'): Counter({'артиллерии': 1, '.': 1}),
#              ('капитаном', 'артиллерии'): Counter({',': 1}),
#              ('артиллерии', ','): Counter({'отличился': 1, 'ни': 1, 'а': 1}),
#              (',', 'отличился'): Counter({'в': 1}),
#              ('отличился', 'в'): Counter({'испанской': 1}),
#              ('в', 'испанской'): Counter({'войне': 1}),
#              ('испанской', 'войне'): Counter({'и': 1}),
#              ('войне', 'и'): Counter({',': 2}),
#              ('и',
#               ','): Counter({'тяжело': 1,
#                       'крайне': 1,
#                       'не': 7,
#                       'взяв': 4,
#                       'вероятно': 4,
#                       'казалось': 8,
#                       'потупя': 1,
#                       'обратясь': 7,
#                       'опасаясь': 1,
#                       'объявив': 1,
#                       'падая': 1,
#                       'кажется': 2,
#                       'снова': 1,
#                       'почти': 1,
#                       'повинуясь': 1,
#                       'сам': 1,
#                       'бог': 1,
#                       'закрывая': 1,
#                       'казалося': 1,
#                       'покраснев': 1,
#                       'протекши': 1,
#                       'найдя': 1,
#                       'следовательно': 2,
#                       'как': 2,
#                       'будучи': 1,
#                       'подступя': 1,
#                       'бросая': 1,
#                       'помянутого': 1,
#                       'если': 1,
#                       'сев': 1,
#                       'поставя': 1,
#                       'перекрестясь': 1,
#                       'оставя': 3,
#                       'милостиво': 1,
#                       'соединясь': 1,
#                       'разъезжая': 1,
#                       'мелко': 1,
#                       'прискакав': 1,
#                       'усумнясь': 1,
#                       'встреченный': 1,
#                       'ставя': 1,
#                       'вдруг': 2,
#                       'задержав': 1,
#                       'обратя': 1,
#                       'рассея': 1,
#                       'растянувшись': 1,
#                       'видя': 2,
#                       'с': 1,
#                       'составя': 1,
#                       'валяясь': 1,
#                       'чувствуя': 1,
#                       'напоив': 1,
#                       'на': 1,
#                       'захватив': 1,
#                       'завидуя': 1,
#                       'зажегши': 1,
#                       'несмотря': 3,
#                       '27': 1,
#                       'вышед': 1,
#                       'остановясь': 1,
#                       'разделив': 1,
#                       'подобно': 1,
#                       'подозвав': 2,
#                       'спрошенная': 1,
#                       'к': 1,
#                       'по': 3,
#                       'пользуясь': 1,
#                       'после': 1,
#                       'взглянув': 3,
#                       'чтоб': 2,
#                       'полно': 1,
#                       'слава': 3,
#                       'слышно': 1,
#                       'наконец': 3,
#                       'матушка': 1,
#                       'сняв': 1,
#                       'положив': 1,
#                       'кивая': 1,
#                       'пустое': 1,
#                       'поцеловав': 1,
#                       'тотчас': 1,
#                       'поужинав': 1,
#                       'в': 3,
#                       'засуча': 1,
#                       'когда': 2,
#                       'впервые': 1,
#                       'приподняв': 1,
#                       'избавляя': 1,
#                       'узнав': 3,
#                       'нагулявшись': 1,
#                       'может': 2,
#                       'заплакав': 1,
#                       'притащив': 1,
#                       'досадуя': 1,
#                       'гнуся': 1,
#                       'мой': 1,
#                       'наклонясь': 1,
#                       'благодаря': 1,
#                       'чтобы': 1,
#                       'che': 1,
#                       'смотря': 1,
#                       'откупоривая': 1,
#                       'поравнявшись': 1,
#                       'немного': 1,
#                       'сколько': 1,
#                       'шутя': 1}),
#              (',', 'тяжело'): Counter({'раненный': 1}),
#              ('тяжело', 'раненный'): Counter({',': 1}),
#              ('раненный', ','): Counter({'возвратился': 1}),
#              (',', 'возвратился'): Counter({'в': 3}),
#              ('возвратился',
#               'в'): Counter({'париж': 1,
#                       'гостиную': 1,
#                       'залу': 2,
#                       'город': 1,
#                       'бердскую': 1,
#                       'берду': 1,
#                       'самару': 1,
#                       'оренбург': 1,
#                       'крепость': 1,
#                       'лагерь': 1,
#                       'свой': 1,
#                       'казань': 1,
#                       'деревню': 1,
#                       'свою': 1,
#                       'назначенное': 1}),
#              ('в', 'париж'): Counter({'.': 2, 'и': 2}),
#              ('париж', '.'): Counter({'император': 1, 'француз': 1}),
#              ('.', 'император'): Counter({'посреди': 1}),
#              ('император', 'посреди'): Counter({'обширных': 1}),
#              ('посреди', 'обширных'): Counter({'своих': 1}),
#              ('обширных', 'своих'): Counter({'трудов': 1}),
#              ('своих', 'трудов'): Counter({'не': 1}),
#              ('трудов', 'не'): Counter({'преставал': 1}),
#              ('не', 'преставал'): Counter({'осведомляться': 1}),
#              ('преставал', 'осведомляться'): Counter({'о': 1}),
#              ('осведомляться', 'о'): Counter({'своем': 1}),
#              ('о',
#               'своем'): Counter({'любимце': 1,
#                       'здоровии': 1,
#                       'косматом': 1,
#                       'французе': 1,
#                       'названии': 1,
#                       'уроне': 1,
#                       'приближении': 1,
#                       'поражении': 1,
#                       'освобождении': 1,
#                       'уже': 1,
#                       'намерении': 5,
#                       'спасении': 1,
#                       'отчаянном': 1,
#                       'сыне': 1,
#                       'вожатом': 1,
#                       'разговоре': 1,
#                       'проигрыше': 1}),
#              ('своем', 'любимце'): Counter({'и': 1}),
#              ('любимце', 'и'): Counter({'всегда': 1}),
#              ('и', 'всегда'): Counter({'получал': 1, 'с': 2}),
#              ('всегда', 'получал'): Counter({'лестные': 1}),
#              ('получал', 'лестные'): Counter({'отзывы': 1}),
#              ('лестные', 'отзывы'): Counter({'насчет': 1}),
#              ('отзывы', 'насчет'): Counter({'его': 1}),
#              ('насчет', 'его'): Counter({'успехов': 1, 'владения': 1}),
#              ('его', 'успехов'): Counter({'и': 1}),
#              ('успехов', 'и'): Counter({'поведения': 1}),
#              ('и', 'поведения'): Counter({'.': 1}),
#              ('поведения', '.'): Counter({'петр': 1}),
#              ('.',
#               'петр'): Counter({'был': 2,
#                       'поцеловал': 1,
#                       'со': 1,
#                       ',': 2,
#                       'сел': 1,
#                       'уехал': 1,
#                       'андреич': 3,
#                       'петрович': 1}),
#              ('петр', 'был'): Counter({'очень': 2}),
#              ('был', 'очень'): Counter({'им': 1, 'доволен': 2, 'не': 1}),
#              ('очень', 'им'): Counter({'доволен': 1, 'довольна': 1}),
#              ('им', 'доволен'): Counter({'и': 1, ',': 1}),
#              ('доволен', 'и'): Counter({'неоднократно': 1}),
#              ('и', 'неоднократно'): Counter({'звал': 1, 'вызывался': 1}),
#              ('неоднократно', 'звал'): Counter({'его': 1}),
#              ('звал', 'его'): Counter({'в': 1}),
#              ('его',
#               'в'): Counter({'россию': 1,
#                       'дальний': 1,
#                       'притворстве': 1,
#                       'какой': 1,
#                       'плен': 1,
#                       'полк': 1,
#                       'той': 1,
#                       'кистеневку': 1,
#                       'разъездах': 1,
#                       'деревне': 2,
#                       'медвежьей': 1,
#                       'ухо': 2,
#                       'дупло': 2,
#                       'другую': 1,
#                       'мечетной': 1,
#                       'казенную': 1,
#                       'клевете': 1,
#                       'ту': 1,
#                       'верхнюю': 1,
#                       'каргале': 1,
#                       'своем': 1,
#                       'живых': 1,
#                       'петрозаводской': 1,
#                       'двенадцати': 1,
#                       'колодку': 1,
#                       'симбирск': 2,
#                       'спину': 1,
#                       'службу': 1,
#                       'сторону': 1,
#                       'глаза': 1,
#                       'саду': 1,
#                       'приказную': 1,
#                       'толпе': 1,
#                       'себя': 1,
#                       'тюрьму': 1,
#                       'сильвио': 1,
#                       'полку': 1,
#                       'числе': 1}),
#              ('в',
#               'россию'): Counter({',': 2,
#                       'или': 1,
#                       '.': 2,
#                       'с': 1,
#                       'в': 2,
#                       'о': 1,
#                       'pour': 1}),
#              ('россию', ','): Counter({'но': 1, 'куда': 1, 'где': 1}),
#              (',',
#               'но'): Counter({'ибрагим': 1,
#                       'уже': 7,
#                       'по': 6,
#                       'безо': 1,
#                       'даже': 9,
#                       'предубежденный': 1,
#                       'вскоре': 3,
#                       'с': 4,
#                       'что': 9,
#                       'остался': 1,
#                       'почтительно': 1,
#                       'деятельные': 1,
#                       'дверь': 2,
#                       'ассамблея': 1,
#                       'со': 1,
#                       'господин': 1,
#                       'зашатался': 1,
#                       'еще': 5,
#                       'его': 1,
#                       'в': 9,
#                       'молчали': 1,
#                       'покраснев': 1,
#                       ',': 11,
#                       'не': 15,
#                       'воображение': 1,
#                       'случалось': 1,
#                       'так': 2,
#                       'дубровский': 3,
#                       'кирила': 1,
#                       'оно': 1,
#                       'только': 2,
#                       'впоследствии': 1,
#                       'мысль': 2,
#                       'силы': 1,
#                       'какая': 1,
#                       'мысли': 1,
#                       'отец': 2,
#                       'последние': 1,
#                       'где': 1,
#                       'владимир': 1,
#                       'наконец': 1,
#                       'обходился': 1,
#                       'у': 2,
#                       'принужден': 1,
#                       'и': 14,
#                       'хозяин': 1,
#                       'знания': 1,
#                       'г': 1,
#                       'было': 1,
#                       'слух': 1,
#                       'могло': 1,
#                       'при': 1,
#                       'дубровского': 1,
#                       'она': 5,
#                       'колебалась': 1,
#                       'марья': 1,
#                       'он': 9,
#                       'хвалил': 1,
#                       'князь': 1,
#                       'решился': 1,
#                       'скрыл': 1,
#                       'бурное': 1,
#                       'тонкий': 1,
#                       'велите': 1,
#                       'саша': 3,
#                       'молчала': 2,
#                       'когда': 1,
#                       'ему': 1,
#                       'глаза': 1,
#                       'офицер': 1,
#                       'незнакомец': 1,
#                       'делать': 2,
#                       'вдруг': 2,
#                       'добросовестный': 1,
#                       'ниже': 1,
#                       'от': 5,
#                       'нарочитой': 1,
#                       'были': 6,
#                       'напоследок': 1,
#                       'они': 3,
#                       'действительно': 1,
#                       'молва': 2,
#                       'отъехали': 1,
#                       'был': 2,
#                       'о': 3,
#                       'всегда': 2,
#                       'заев': 1,
#                       'прежде': 2,
#                       'мало': 1,
#                       'пред': 1,
#                       'сочинитель': 1,
#                       'принуждены': 1,
#                       'для': 4,
#                       'наполненную': 1,
#                       'предводитель': 1,
#                       'шесть': 1,
#                       'духовенством': 1,
#                       'никто': 1,
#                       'буду': 1,
#                       'мы': 2,
#                       'третий': 1,
#                       'это': 1,
#                       'благонадежны': 1,
#                       'простые': 1,
#                       'я': 4,
#                       'нетерпение': 1,
#                       'мне': 1,
#                       'скоро': 2,
#                       'рассказываемых': 1,
#                       'курганов': 1,
#                       'скорее': 1,
#                       '**': 1,
#                       'все': 3,
#                       'также': 1,
#                       'столь': 2,
#                       'более': 1,
#                       'равняются': 1,
#                       'никак': 1,
#                       'годовщиною': 1,
#                       'тот': 1,
#                       'ветрен': 1,
#                       'ничего': 1,
#                       'довольно': 1,
#                       'плутовское': 1,
#                       'чрезвычайно': 1,
#                       'самый': 1,
#                       'иван': 1,
#                       'старик': 1,
#                       'чувствовал': 1,
#                       'ни': 2,
#                       'сильных': 1,
#                       'сладостные': 1,
#                       'между': 1,
#                       'пугачев': 2,
#                       'растерзанного': 1,
#                       'смелым': 1,
#                       'как': 1,
#                       'приписала': 1,
#                       'мой': 1,
#                       'двери': 1,
#                       'отеческое': 1,
#                       'кирпич': 1,
#                       'война': 1,
#                       'тут': 1,
#                       'хохлатая': 1,
#                       'нашла': 1,
#                       'сохраняла': 1,
#                       'твердость': 1,
#                       'необходимое': 1,
#                       'дети': 1,
#                       'ее': 1,
#                       'надобно': 1,
#                       'улыбка': 1,
#                       'умеренный': 1,
#                       'стыдливость': 1,
#                       'единственно': 1,
#                       'шампанское': 1,
#                       'смолоду': 1,
#                       'волнение': 1,
#                       'чем': 1,
#                       'одна': 1,
#                       'сказавший': 1,
#                       'остановился': 1,
#                       'смерть': 1,
#                       '–': 1,
#                       'непонятное': 1,
#                       'гробовщик': 1,
#                       'второпях': 1,
#                       'опрятную': 1,
#                       'дуни': 1,
#                       'молчал': 2,
#                       'на': 2,
#                       'шутки': 1,
#                       'дерн': 1,
#                       'удержало': 1,
#                       'никогда': 1,
#                       'молодая': 1,
#                       'находя': 1,
# ...
#                       'необходимо': 1,
#                       'где': 1,
#                       'рано': 1,
#                       'да': 3,
#                       'произнес': 1,
#                       'подавай': 1,
#                       'закричал': 5,
#                       'беда': 1,
#                       'невесть': 1,
#                       'воротился': 1,
#                       'смотри': 1,
#                       'воз': 1,
#                       'знаешь': 1,
#                       'слава': 2,
#                       'почему': 1,
#                       'говорит': 1,
#                       'отец': 1,
#                       'это': 1,
#                       'прикажите': 1,
#                       'опять': 1,
#                       'будет': 2,
#                       'пропью': 1,
#                       'сейчас': 2,
#                       'обходиться': 1,
#                       'все': 6,
#                       'к': 1,
#                       'наши': 1,
#                       'у': 3,
#                       'только': 1,
#                       'прибавил': 4,
#                       'нечего': 1,
#                       'ведь': 1,
#                       'оставаться': 1,
#                       'баба': 1,
#                       'так': 5,
#                       'сдержишь': 1,
#                       'добро': 1,
#                       'делайте': 1,
#                       'без': 1,
#                       'худой': 1,
#                       'одобряет': 1,
#                       'надобно': 1,
#                       'доносить': 1,
#                       'василиса': 1,
#                       'когда': 2,
#                       'будь': 2,
#                       'прибавила': 1,
#                       'со': 1,
#                       'повторял': 1,
#                       'вот': 2,
#                       'посмотри': 1,
#                       'посмотрим': 1,
#                       'коли': 1,
#                       'мысль': 1,
#                       'али': 1,
#                       'тогда': 1,
#                       'видно': 1,
#                       'оставайся': 1,
#                       'прощай': 1,
#                       'дорога': 1,
#                       'дома': 1,
#                       'теперь': 3,
#                       'государю': 1,
#                       'затянем': 1,
#                       'смейся': 1,
#                       'прощайте': 1,
#                       'примолвил': 1,
#                       'жалует': 1,
#                       'вечно': 1,
#                       'надлежит': 1,
#                       'прибегаю': 1,
#                       'пишет': 1,
#                       'нежели': 1,
#                       'отдай': 1,
#                       'волен': 1,
#                       'от': 1,
#                       'подхватил': 1,
#                       'помня': 1,
#                       'управился': 1,
#                       'поздно': 1,
#                       'можно': 1,
#                       'дворянин': 1,
#                       'словом': 1,
#                       'говорили': 1,
#                       'три': 2,
#                       'отопри': 1,
#                       'довольно': 1,
#                       'пошли': 1,
#                       'бог': 1,
#                       'отвечали': 2,
#                       'с': 3,
#                       'дорылись': 1,
#                       'каким': 1,
#                       'отыгрался': 1,
#                       'она': 2,
#                       'пришли': 1,
#                       'карету': 1,
#                       'всегда': 1,
#                       'однажды': 1,
#                       'офицер': 1,
#                       'подымала': 1,
#                       'думал': 1,
#                       'пожалуй': 1,
#                       'через': 1,
#                       'эта': 1,
#                       'вперед': 1,
#                       'было': 1,
#                       'составить': 1,
#                       'клянусь': 1,
#                       'назначить': 1,
#                       'сердце': 1,
#                       'всем': 1,
#                       'человека': 1,
#                       'лицо': 1,
#                       'или': 1,
#                       'пистолет': 1,
#                       'дети': 1,
#                       'бодрствующую': 1,
#                       'воспользоваться': 1,
#                       'извините': 1,
#                       'бьете': 1,
#                       'неужели': 1,
#                       'пускай': 1,
#                       'заметили': 1,
#                       'm': 2,
#                       'возразила': 1,
#                       'чтобы': 1,
#                       'охота': 1,
#                       'спросила': 1,
#                       'княжна': 1,
#                       'ознаменовали': 1,
#                       'может': 1,
#                       'сеникур': 1,
#                       'твой': 1}),
#              ('—',
#               'а'): Counter({'уже': 1,
#                       'дура': 1,
#                       'кто': 1,
#                       'что': 4,
#                       'то': 1,
#                       'признаюсь': 1,
#                       'за': 1,
#                       'я': 3,
#                       'это': 1,
#                       'все': 1,
#                       'господа': 1,
#                       'видишь': 1,
#                       'вон': 1,
#                       'почему': 3,
#                       '!': 2,
#                       'марья': 2,
#                       'потому': 1,
#                       'с': 1,
#                       'как': 1,
#                       'слышно': 1,
#                       'вот': 1,
#                       'слышь': 1,
#                       'он': 1,
#                       'народ': 1,
#                       'ты': 1,
#                       'знаешь': 1,
#                       'где': 1,
#                       'каков': 1,
#                       'если': 1,
#                       'разве': 1,
#                       'между': 1,
#                       'ей': 1,
#                       'наполеон': 1}),
#              ('а', 'уже'): Counter({'видеть': 1, 'любила': 1}),
#              ('уже', 'видеть'): Counter({'графиню': 1}),
#              ('видеть', 'графиню'): Counter({'каждый': 1}),
#              ('графиню', 'каждый'): Counter({'день': 1}),
#              ('каждый',
#               'день'): Counter({'было': 1,
#                       'был': 1,
#                       'бывали': 1,
#                       'ожидали': 1,
#                       'багренья': 1,
#                       '.': 1,
#                       'бродила': 1,
#                       'находил': 1,
#                       'тихонько': 1,
#                       ';': 1,
#                       'будем': 1,
#                       'поминали': 1,
#                       'получала': 1,
#                       'со': 1,
#                       ',': 2,
#                       'гробов': 1}),
#              ('день', 'было'): Counter({'для': 1}),
#              ('было',
#               'для'): Counter({'него': 2,
#                       'них': 1,
#                       'меня': 2,
#                       'нее': 2,
#                       'его': 1}),
#              ('него', 'необходимо'): Counter({'.': 1}),
#              ('необходимо', '.'): Counter({'он': 1}),
#              ('он', 'повсюду'): Counter({'искал': 1}),
#              ('повсюду', 'искал'): Counter({'ее': 1}),
#              ('искал', 'ее'): Counter({'встречи': 1}),
#              ('ее', 'встречи'): Counter({',': 1}),
#              ('встречи', ','): Counter({'и': 1, 'остановились': 1, 'она': 1}),
#              ('и', 'встреча'): Counter({'с': 1}),
#              ('встреча', 'с'): Counter({'нею': 1}),
#              ('с',
#               'нею'): Counter({'казалась': 1,
#                       'наедине': 2,
#                       'менуэт': 1,
#                       'познакомлю': 1,
#                       'случилось': 1,
#                       ',': 2,
#                       'со': 1,
#                       'разговаривающего': 1,
#                       'за': 1,
#                       'не': 3,
#                       'села': 1,
#                       'носились': 1,
#                       'губернии': 1,
#                       'туда': 1,
#                       'в': 1,
#                       'маша': 1,
#                       '?': 1,
#                       'будет': 1,
#                       'всегдашние': 1,
#                       'ни': 1,
#                       'разговорилась': 2,
#                       '.': 1,
#                       'был': 1,
#                       'бесконечную': 1,
#                       'когда': 1,
#                       'разговаривать': 1,
#                       'по': 1,
#                       'обдумывала': 1,
#                       'равняться': 1,
#                       'самою': 1,
#                       'любезничали': 1}),
#              ('нею', 'казалась'): Counter({'ему': 1}),
#              ('казалась', 'ему'): Counter({'каждый': 1, 'столь': 1, 'так': 1}),
#              ('ему', 'каждый'): Counter({'раз': 1}),
#              ('каждый', 'раз'): Counter({'неожиданной': 1}),
#              ('раз', 'неожиданной'): Counter({'милостию': 1}),
#              ('неожиданной', 'милостию'): Counter({'неба': 1}),
#              ('милостию', 'неба'): Counter({'.': 1}),
#              ('неба', '.'): Counter({'графиня': 1, 'с': 1, '—': 1}),
#              ('графиня',
#               ','): Counter({'прежде': 1,
#                       'испуганная': 1,
#                       'привыкшая': 1,
#                       'ее': 1,
#                       'совсем': 1,
#                       '—': 1,
#                       'чуть': 1,
#                       'казалось': 1,
#                       'и': 1,
#                       'с': 1,
#                       '–': 2}),
#              (',',
#               'прежде'): Counter({'чем': 4,
#                       'сего': 1,
#                       'бывшего': 1,
#                       'так': 1,
#                       'ею': 1}),
#              ('прежде',
#               'чем'): Counter({'он': 1,
#                       'к': 1,
#                       'приступим': 1,
#                       'марья': 1,
#                       'успел': 1}),
#              ('чем',
#               'он'): Counter({'сам': 1,
#                       'изволил': 1,
#                       'кончил': 1,
#                       'меня': 1,
#                       'кончит': 1}),
#              ('он',
#               'сам'): Counter({',': 2,
#                       'был': 1,
#                       'себе': 2,
#                       'сгорел': 1,
#                       'себя': 1,
#                       'предводительствовал': 1,
#                       'ездил': 1,
#                       '.': 1,
#                       'вышел': 1,
#                       'находился': 1,
#                       ')': 1,
#                       'позволить': 1,
#                       'у': 1}),
#              ('сам',
#               ','): Counter({'угадала': 1,
#                       '—': 1,
#                       'разговор': 1,
#                       'заняв': 1,
#                       'что': 1,
#                       'подобрал': 1,
#                       '–': 1}),
#              (',', 'угадала'): Counter({'его': 1}),
#              ('угадала', 'его'): Counter({'чувства': 1}),
#              ('его', 'чувства'): Counter({'.': 1}),
#              ('чувства', '.'): Counter({'что': 1}),
#              ('.',
#               'что'): Counter({'ни': 1,
#                       'делать': 2,
#                       'же': 5,
#                       '-': 3,
#                       'ж': 4,
#                       'ты': 2,
#                       'мною': 1,
#                       'из': 1,
#                       ',': 1,
#                       'будет': 2,
#                       'мне': 2,
#                       'заутра': 1,
#                       'возговорит': 1,
#                       'было': 1,
#                       'тогда': 1,
#                       'за': 1,
#                       'пользы': 1,
#                       'касается': 3,
#                       'такое': 1,
#                       'подумает': 1,
#                       '?': 1}),
#              ('что',
#               'ни'): Counter({'говори': 2,
#                       'на': 1,
#                       'прикажет': 1,
#                       'единое': 1,
#                       'делал': 1,
#                       'о': 1,
#                       'есть': 1}),
#              ('ни', 'говори'): Counter({',': 2}),
#              ('говори', ','): Counter({'а': 1, 'поэты': 1, 'кто': 1}),
#              ('а', 'любовь'): Counter({'без': 1}),
#              ('любовь', 'без'): Counter({'надежд': 1}),
#              ('без', 'надежд'): Counter({'и': 1}),
#              ('надежд', 'и'): Counter({'требований': 1}),
#              ('и', 'требований'): Counter({'трогает': 1}),
#              ('требований', 'трогает'): Counter({'сердце': 1}),
#              ('трогает', 'сердце'): Counter({'женское': 1}),
#              ('сердце', 'женское'): Counter({'вернее': 1}),
#              ('женское', 'вернее'): Counter({'всех': 1}),
#              ('вернее', 'всех'): Counter({'расчетов': 1}),
#              ('всех', 'расчетов'): Counter({'обольщения': 1}),
#              ('расчетов', 'обольщения'): Counter({'.': 1}),
#              ('обольщения', '.'): Counter({'в': 1}),
#              ('в',
#               'присутствии'): Counter({'ибрагима': 1,
#                       'духовенства': 1,
#                       'своей': 1,
#                       'жены': 1,
#                       'комиссии': 1,
#                       'ивана': 1,
#                       'лизы': 1,
#                       'слуг': 1}),
#              ('присутствии', 'ибрагима'): Counter({'графиня': 1}),
#              ('ибрагима', 'графиня'): Counter({'следовала': 1}),
#              ('графиня', 'следовала'): Counter({'за': 1}),
#              ('следовала', 'за'): Counter({'всеми': 1}),
#              ('за', 'всеми'): Counter({'его': 1, 'ее': 1}),
#              ('всеми', 'его'): Counter({'движениями': 1}),
#              ('его', 'движениями'): Counter({',': 1}),
#              ('движениями',
#               ','): Counter({'вслушивалась': 1,
#                       'свойственными': 1,
#                       'испугалась': 1}),
#              (',', 'вслушивалась'): Counter({'во': 1}),
#              ('вслушивалась', 'во'): Counter({'все': 1}),
#              ('во',
#               'все'): Counter({'его': 1,
#                       'стороны': 17,
#                       'опасности': 1,
#                       ',': 1,
#                       'это': 2,
#                       'горло': 3,
#                       'места': 1,
#                       'время': 5,
#                       'сие': 1,
#                       'продолжение': 2,
#                       'заставы': 1,
#                       'таинства': 1}),
#              ('все',
#               'его'): Counter({'речи': 1,
#                       'дети': 1,
#                       'приказания': 1,
#                       'свычаи': 1,
#                       'товарищи': 1,
#                       'ожидали': 1,
#                       'добро': 1,
#                       'имение': 1}),
#              ('его', 'речи'): Counter({';': 1, 'сильно': 1}),
#              ('речи', ';'): Counter({'без': 1}),
#              (';', 'без'): Counter({'него': 1}),
#              ('без', 'него'): Counter({'она': 1, 'скучал': 1, 'не': 1}),
#              ('него', 'она'): Counter({'задумывалась': 1}),
#              ('она', 'задумывалась'): Counter({'и': 1}),
#              ('задумывалась', 'и'): Counter({'впадала': 1}),
#              ('и', 'впадала'): Counter({'в': 1}),
#              ('впадала', 'в'): Counter({'обыкновенную': 1}),
#              ('в', 'обыкновенную'): Counter({'свою': 1}),
#              ('обыкновенную', 'свою'): Counter({'рассеянность': 1}),
#              ('свою', 'рассеянность'): Counter({'...': 1}),
#              ('рассеянность', '...'): Counter({'мервиль': 1}),
#              ('...', 'мервиль'): Counter({'первый': 1}),
#              ('мервиль', 'первый'): Counter({'заметил': 1}),
#              ('первый', 'заметил'): Counter({'эту': 1}),
#              ('заметил', 'эту'): Counter({'взаимную': 1}),
#              ('эту', 'взаимную'): Counter({'склонность': 1}),
#              ('взаимную', 'склонность'): Counter({'и': 3, ',': 1}),
#              ('склонность',
#               'и'): Counter({'поздравил': 1,
#                       'старался': 1,
#                       'доверчивость': 1}),
#              ('и', 'поздравил'): Counter({'ибрагима': 1, 'его': 1}),
#              ...})

# %%
def generate_text(model, seed_text, num_words=50):
    text = seed_text.split()

    if len(text) < 2:
        while len(text) != 2:
            text.append(random.choice(list(model.keys()))[0])

    while len(text) < num_words:        
        w1, w2 = text[-2].lower(), text[-1].lower()
        
        # Получаем вероятные продолжения (слово3)
        next_words = model.get((w1, w2))

        if next_words:
            words = list(next_words.keys())
            words_count = list(next_words.values())

            next_word = words[np.argmax(words_count)]

            text.append(next_word)
        else:
            text.append(random.choice(list(model.keys()))[0])
        
    return ' '.join(text)

# %%
seed_text = 'я император'

# %%
generated_text = generate_text(model, seed_text, num_words=50)
generated_text
# Out:
# 'я император петрович шибко прочие несли стащили тебе - приходили жестокое у вдруг благопристойно греха величайшим гренадеры татищевой к главе первой 1 некоторые из его шайки . он был в таком случае , что он не мог не улыбнуться . императрица , досадуя на сплетни европейские , отвечала с какою'

# %%
seed_text = ''

# %%
generated_text = generate_text(model, seed_text, num_words=50)
generated_text
# Out:
# 'вольность молодую тройкою оной вальсы кармана федоровым дубровский всех бегут . караулами давыдовым оскорбительных они и очистят воровскую рощу ; народ не трусливый , каждый в одиночку на медведя ходит – от разбойников не попятятся . – а что нам делать , коли не наша воля ? — спросил я'
